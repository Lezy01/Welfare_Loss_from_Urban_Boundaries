# %% [markdown]
# ### Rent Curve Estimation
#
# This step focuses on estimating the relationship between land price and distance to the city center. The point with the highest observed land price is used as the city center. Distances from each land parcel to the center are computed, and a regression of land price on distance is performed to obtain the **rent curve**.
#
# The procedure includes the following components:
#
#
# 1. **Rural Land Price Estimation**
#
#    * Match rural land rent data with corresponding province-city (or municipality-county) to produce the file `agr_val_with_admin.csv`, and save city-specific results to the `/Agr_lp` folder.
#    * Filter out data points located within built-up areas to focus on rural land only.
#    * Compute the average present value of rural land prices for each city.
#
# 2. **Rent Curve Fitting**
#
#    * Convert housing prices into land prices: based on the Cobb-Douglas production function, we estimate the share of land in production (denoted by $\alpha$), and then compute unit land price as
#
#      $$
#      \text{Land Price} = \alpha \times \text{Housing Price}
#      $$
#    * Perform an OLS regression of land price on distance to obtain the rent curve.
#
# 3. **Welfare Loss Estimation**
#
#    * Compute the theoretical urban boundary (based on rural-urban land price equality).
#    * Measure the gap between the actual and theoretical urban-rural boundaries.
#    * Use this gap to calculate the triangular **welfare loss** caused by constrained urban expansion.

# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from geopy.distance import geodesic
import statsmodels.api as sm
import re
from shapely.ops import unary_union
import numpy as np

# %% [markdown]
# ## Average Rural Land Price
#
# ### Split Rural Land Rent Data and Match with Province, City, and County
#
# I begin by processing the raw rural land rent dataset. This involves:
#
# * Splitting the data by administrative regions (province, city, county);
# * Matching each entry with its corresponding administrative unit;
# * Ensuring consistent naming conventions and accurate alignment with shapefiles or statistical boundaries used in downstream analysis.
#
# This step produces city- or county-level rural land price files, which serve as the basis for computing average rural land values in each region.

# %%
agr_path = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/agr_val_2022.csv"
admin_path = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Raw/China_Adm_2020/China2020County.shp"
output_path = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/agr_val_with_admin.csv"


df = pd.read_csv(agr_path)
gdf_agr = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat), crs="EPSG:4326")


gdf_admin = gpd.read_file(admin_path).to_crs("EPSG:4326")
gdf_admin = gdf_admin.rename(columns={
    "NAME_1": "province",
    "NAME_2": "city",
    "NAME_3": "county"
})
if not gdf_admin.is_valid.all():
    gdf_admin["geometry"] = gdf_admin.buffer(0)


gdf_joined = gpd.sjoin(
    gdf_agr,
    gdf_admin[["province", "city", "county", "geometry"]],
    how="left",
    predicate="intersects"
)


n_total = len(gdf_joined)
n_matched = gdf_joined["province"].notna().sum()
match_rate = n_matched / n_total * 100

print(f"successfully matched {n_matched} out of {n_total} points.")
print(f"match rate: {match_rate:.2f}%")


gdf_joined.drop(columns=["geometry", "index_right"], inplace=True)
gdf_joined = gdf_joined.dropna(subset=["province"])
gdf_joined.to_csv(output_path, index=False)


print(f"completed! The output file is saved at {output_path}.")
# Out:
# successfully matched 73003 out of 157267 points.
# match rate: 46.42%
# completed! The output file is saved at /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/agr_val_with_admin.csv.

# %%
agr_path = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/agr_val_with_admin.csv"
agr_output_dir = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp"
os.makedirs(agr_output_dir, exist_ok=True)

df = pd.read_csv(agr_path)

df["city"] = df["city"].replace(["NULL", "null", "", "NaN", "nan"], pd.NA)

def generate_prov_city(row):
    if pd.notna(row["city"]):
        return f"{row['province']}-{row['city']}"
    elif pd.notna(row["county"]):
        return f"{row['province']}-{row['county']}"
    else:
        return pd.NA

df["prov_city"] = df.apply(generate_prov_city, axis=1)


for prov_city, group in df.groupby("prov_city"):
    if pd.isna(prov_city):
        continue

    filename = f"{prov_city.strip().replace(' ', '_')}_agr_lp.csv"
    output_path = os.path.join(agr_output_dir, filename)

    group.to_csv(output_path, index=False)
    print(f"saved {len(group)} points to {output_path}")

print("completed!")
# Out:
# saved 182 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Anqing_agr_lp.csv
# saved 82 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Bengbu_agr_lp.csv
# saved 117 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Bozhou_agr_lp.csv
# saved 111 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Chizhou_agr_lp.csv
# saved 191 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Chuzhou_agr_lp.csv
# saved 141 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Fuyang_agr_lp.csv
# saved 154 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Hefei_agr_lp.csv
# saved 35 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Huaibei_agr_lp.csv
# saved 78 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Huainan_agr_lp.csv
# saved 131 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Huangshan_agr_lp.csv
# saved 210 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Liuan_agr_lp.csv
# saved 57 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Maanshan_agr_lp.csv
# saved 146 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Suzhou_agr_lp.csv
# saved 42 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Tongling_agr_lp.csv
# saved 85 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Wuhu_agr_lp.csv
# saved 165 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Anhui-Xuancheng_agr_lp.csv
# saved 21 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Changping_agr_lp.csv
# saved 5 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Chaoyang_agr_lp.csv
# saved 16 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Daxing_agr_lp.csv
# saved 30 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Fangshan_agr_lp.csv
# saved 6 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Fengtai_agr_lp.csv
# saved 6 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Haidian_agr_lp.csv
# saved 32 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Huairou_agr_lp.csv
# saved 20 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Mentougou_agr_lp.csv
# saved 37 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Miyun_agr_lp.csv
# saved 12 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Pinggu_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Shijingshan_agr_lp.csv
# saved 14 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Shunyi_agr_lp.csv
# saved 13 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Tongzhou_agr_lp.csv
# saved 31 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Beijing-Yanqing_agr_lp.csv
# saved 26 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Banan_agr_lp.csv
# saved 9 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Beibei_agr_lp.csv
# saved 13 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Bishan_agr_lp.csv
# saved 20 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Changshou_agr_lp.csv
# saved 42 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Chengkou_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Dadukou_agr_lp.csv
# saved 18 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Dazu_agr_lp.csv
# saved 21 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Dianjiang_agr_lp.csv
# saved 38 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Fengdu_agr_lp.csv
# saved 53 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Fengjie_agr_lp.csv
# saved 40 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Fuling_agr_lp.csv
# saved 33 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Hechuan_agr_lp.csv
# saved 3 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Jiangbei_agr_lp.csv
# saved 40 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Jiangjin_agr_lp.csv
# saved 6 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Jiulongpo_agr_lp.csv
# saved 55 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Kaizhou_agr_lp.csv
# saved 26 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Liangping_agr_lp.csv
# saved 3 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Nanan_agr_lp.csv
# saved 34 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Nanchuan_agr_lp.csv
# saved 50 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Pengshuimiaozuandtujiazu_agr_lp.csv
# saved 30 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Qianjiang_agr_lp.csv
# saved 38 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Qijiang_agr_lp.csv
# saved 16 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Rongchang_agr_lp.csv
# saved 6 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Shapingba_agr_lp.csv
# saved 40 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Shizhutujiazu_agr_lp.csv
# saved 19 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Tongliang_agr_lp.csv
# saved 21 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Tongnan_agr_lp.csv
# saved 46 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Wanzhou_agr_lp.csv
# saved 39 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Wulong_agr_lp.csv
# saved 42 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Wushan_agr_lp.csv
# saved 54 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Wuxi_agr_lp.csv
# saved 32 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Xiushantujiazuandmiaozu_agr_lp.csv
# saved 20 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Yongchuan_agr_lp.csv
# saved 68 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Youyangtujiazuandmiaozu_agr_lp.csv
# saved 18 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Yubei_agr_lp.csv
# saved 51 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Yunyang_agr_lp.csv
# saved 31 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Chongqing-Zhongxian_agr_lp.csv
# saved 149 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Fuzhou_agr_lp.csv
# saved 245 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Longyan_agr_lp.csv
# saved 345 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Nanping_agr_lp.csv
# saved 167 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Ningde_agr_lp.csv
# saved 49 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Putian_agr_lp.csv
# saved 144 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Quanzhou_agr_lp.csv
# saved 296 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Sanming_agr_lp.csv
# saved 19 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Xiamen_agr_lp.csv
# saved 159 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Fujian-Zhangzhou_agr_lp.csv
# saved 232 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Baiyin_agr_lp.csv
# saved 276 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Dingxi_agr_lp.csv
# saved 229 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Gannanzangzu_agr_lp.csv
# saved 12 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Jiayuguan_agr_lp.csv
# saved 66 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Jinchang_agr_lp.csv
# saved 189 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Jiuquan_agr_lp.csv
# saved 151 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Lanzhou_agr_lp.csv
# saved 113 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Linxiahuizu_agr_lp.csv
# saved 379 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Longnan_agr_lp.csv
# saved 157 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Pingliang_agr_lp.csv
# saved 351 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Qingyang_agr_lp.csv
# saved 198 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Tianshui_agr_lp.csv
# saved 217 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Wuwei_agr_lp.csv
# saved 215 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Gansu-Zhangye_agr_lp.csv
# saved 39 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Chaozhou_agr_lp.csv
# saved 29 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Dongguan_agr_lp.csv
# saved 49 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Foshan_agr_lp.csv
# saved 88 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Guangzhou_agr_lp.csv
# saved 199 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Heyuan_agr_lp.csv
# saved 143 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Huizhou_agr_lp.csv
# saved 114 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Jiangmen_agr_lp.csv
# saved 70 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Jieyang_agr_lp.csv
# saved 140 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Maoming_agr_lp.csv
# saved 203 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Meizhou_agr_lp.csv
# saved 239 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Qingyuan_agr_lp.csv
# saved 24 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Shantou_agr_lp.csv
# saved 59 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Shanwei_agr_lp.csv
# saved 234 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Shaoguan_agr_lp.csv
# saved 25 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Shenzhen_agr_lp.csv
# saved 98 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Yangjiang_agr_lp.csv
# saved 104 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Yunfu_agr_lp.csv
# saved 152 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Zhanjiang_agr_lp.csv
# saved 188 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Zhaoqing_agr_lp.csv
# saved 22 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Zhongshan_agr_lp.csv
# saved 16 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangdong-Zhuhai_agr_lp.csv
# saved 463 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Baise_agr_lp.csv
# saved 41 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Beihai_agr_lp.csv
# saved 221 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Chongzuo_agr_lp.csv
# saved 71 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Fangchenggang_agr_lp.csv
# saved 138 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Guigang_agr_lp.csv
# saved 354 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Guilin_agr_lp.csv
# saved 419 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Hechi_agr_lp.csv
# saved 148 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Hezhou_agr_lp.csv
# saved 168 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Laibin_agr_lp.csv
# saved 240 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Liuzhou_agr_lp.csv
# saved 280 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Nanning_agr_lp.csv
# saved 131 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Qinzhou_agr_lp.csv
# saved 158 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Wuzhou_agr_lp.csv
# saved 163 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guangxi-Yulin_agr_lp.csv
# saved 121 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Anshun_agr_lp.csv
# saved 350 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Bijie_agr_lp.csv
# saved 105 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Guiyang_agr_lp.csv
# saved 130 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Liupanshui_agr_lp.csv
# saved 399 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Qiandongnanmiaozudongzu_agr_lp.csv
# saved 341 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Qiannanbuyizumiaozu_agr_lp.csv
# saved 215 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Qianxinanbuyizumiaozu_agr_lp.csv
# saved 238 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Tongren_agr_lp.csv
# saved 407 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Guizhou-Zunyi_agr_lp.csv
# saved 28 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Baishalizu_agr_lp.csv
# saved 14 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Baotinglizumiaozu_agr_lp.csv
# saved 19 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Changjianglizu_agr_lp.csv
# saved 25 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Chengmai_agr_lp.csv
# saved 38 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Danzhou_agr_lp.csv
# saved 14 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Dingan_agr_lp.csv
# saved 27 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Dongfang_agr_lp.csv
# saved 28 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Haikou_agr_lp.csv
# saved 33 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Ledonglizu_agr_lp.csv
# saved 15 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Lingao_agr_lp.csv
# saved 11 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Lingshuilizu_agr_lp.csv
# saved 22 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Qionghai_agr_lp.csv
# saved 36 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Qiongzhonglizuandmiaozu_agr_lp.csv
# saved 23 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Sanya_agr_lp.csv
# saved 18 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Tunchang_agr_lp.csv
# saved 21 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Wanning_agr_lp.csv
# saved 25 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Wenchang_agr_lp.csv
# saved 14 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hainan-Wuzhishan_agr_lp.csv
# saved 331 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Baoding_agr_lp.csv
# saved 206 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Cangzhou_agr_lp.csv
# saved 611 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Chengde_agr_lp.csv
# saved 172 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Handan_agr_lp.csv
# saved 133 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Hengshui_agr_lp.csv
# saved 96 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Langfang_agr_lp.csv
# saved 115 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Qinhuangdao_agr_lp.csv
# saved 205 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Shijiazhuang_agr_lp.csv
# saved 200 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Tangshan_agr_lp.csv
# saved 185 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Xingtai_agr_lp.csv
# saved 559 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hebei-Zhangjiakou_agr_lp.csv
# saved 362 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Daqing_agr_lp.csv
# saved 357 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Daxinganling_agr_lp.csv
# saved 803 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Haerbin_agr_lp.csv
# saved 187 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Hegang_agr_lp.csv
# saved 995 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Heihe_agr_lp.csv
# saved 551 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Jiamusi_agr_lp.csv
# saved 341 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Jixi_agr_lp.csv
# saved 529 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Mudanjiang_agr_lp.csv
# saved 730 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Qiqihaer_agr_lp.csv
# saved 89 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Qitaihe_agr_lp.csv
# saved 347 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Shuangyashan_agr_lp.csv
# saved 564 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Suihua_agr_lp.csv
# saved 315 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Heilongjiang-Yichun_agr_lp.csv
# saved 105 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Anyang_agr_lp.csv
# saved 31 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Hebi_agr_lp.csv
# saved 56 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Jiaozuo_agr_lp.csv
# saved 28 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Jiyuan_agr_lp.csv
# saved 93 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Kaifeng_agr_lp.csv
# saved 38 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Luohe_agr_lp.csv
# saved 215 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Luoyang_agr_lp.csv
# saved 361 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Nanyang_agr_lp.csv
# saved 111 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Pingdingshan_agr_lp.csv
# saved 62 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Puyang_agr_lp.csv
# saved 137 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Sanmenxia_agr_lp.csv
# saved 147 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Shangqiu_agr_lp.csv
# saved 117 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Xinxiang_agr_lp.csv
# saved 259 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Xinyang_agr_lp.csv
# saved 71 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Xuchang_agr_lp.csv
# saved 107 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Zhengzhou_agr_lp.csv
# saved 168 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Zhoukou_agr_lp.csv
# saved 216 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Henan-Zhumadian_agr_lp.csv
# saved 323 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Enshitujiazumiaozu_agr_lp.csv
# saved 22 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Ezhou_agr_lp.csv
# saved 238 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Huanggang_agr_lp.csv
# saved 61 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Huangshi_agr_lp.csv
# saved 168 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Jingmen_agr_lp.csv
# saved 186 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Jingzhou_agr_lp.csv
# saved 27 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Qianjiang_agr_lp.csv
# saved 40 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Shennongjialin_agr_lp.csv
# saved 322 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Shiyan_agr_lp.csv
# saved 132 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Suizhou_agr_lp.csv
# saved 35 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Tianmen_agr_lp.csv
# saved 117 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Wuhan_agr_lp.csv
# saved 272 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Xiangyang_agr_lp.csv
# saved 131 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Xianning_agr_lp.csv
# saved 33 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Xiantao_agr_lp.csv
# saved 121 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Xiaogan_agr_lp.csv
# saved 289 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hubei-Yichang_agr_lp.csv
# saved 245 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Changde_agr_lp.csv
# saved 154 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Changsha_agr_lp.csv
# saved 247 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Chenzhou_agr_lp.csv
# saved 192 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Hengyang_agr_lp.csv
# saved 357 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Huaihua_agr_lp.csv
# saved 104 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Loudi_agr_lp.csv
# saved 271 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Shaoyang_agr_lp.csv
# saved 68 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Xiangtan_agr_lp.csv
# saved 208 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Xiangxitujiazumiaozu_agr_lp.csv
# saved 163 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Yiyang_agr_lp.csv
# saved 280 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Yongzhou_agr_lp.csv
# saved 197 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Yueyang_agr_lp.csv
# saved 125 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Zhangjiajie_agr_lp.csv
# saved 146 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Hunan-Zhuzhou_agr_lp.csv
# saved 61 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Changzhou_agr_lp.csv
# saved 136 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Huaian_agr_lp.csv
# saved 104 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Lianyungang_agr_lp.csv
# saved 85 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Nanjing_agr_lp.csv
# saved 117 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Nantong_agr_lp.csv
# saved 118 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Suqian_agr_lp.csv
# saved 103 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Suzhou_agr_lp.csv
# saved 79 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Taizhou_agr_lp.csv
# saved 63 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Wuxi_agr_lp.csv
# saved 159 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Xuzhou_agr_lp.csv
# saved 201 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Yancheng_agr_lp.csv
# saved 93 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Yangzhou_agr_lp.csv
# saved 51 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangsu-Zhenjiang_agr_lp.csv
# saved 248 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Fuzhou_agr_lp.csv
# saved 510 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Ganzhou_agr_lp.csv
# saved 331 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Jian_agr_lp.csv
# saved 69 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Jingdezhen_agr_lp.csv
# saved 259 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Jiujiang_agr_lp.csv
# saved 93 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Nanchang_agr_lp.csv
# saved 53 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Pingxiang_agr_lp.csv
# saved 298 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Shangrao_agr_lp.csv
# saved 42 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Xinyu_agr_lp.csv
# saved 250 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Yichun_agr_lp.csv
# saved 46 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jiangxi-Yingtan_agr_lp.csv
# saved 421 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Baicheng_agr_lp.csv
# saved 191 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Baishan_agr_lp.csv
# saved 338 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Changchun_agr_lp.csv
# saved 424 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Jilin_agr_lp.csv
# saved 83 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Liaoyuan_agr_lp.csv
# saved 230 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Siping_agr_lp.csv
# saved 343 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Songyuan_agr_lp.csv
# saved 232 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Tonghua_agr_lp.csv
# saved 479 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Jilin-Yanbianchaoxianzu_agr_lp.csv
# saved 144 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Anshan_agr_lp.csv
# saved 131 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Benxi_agr_lp.csv
# saved 308 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Chaoyang_agr_lp.csv
# saved 186 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Dalian_agr_lp.csv
# saved 219 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Dandong_agr_lp.csv
# saved 173 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Fushun_agr_lp.csv
# saved 159 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Fuxin_agr_lp.csv
# saved 153 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Huludao_agr_lp.csv
# saved 151 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Jinzhou_agr_lp.csv
# saved 74 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Liaoyang_agr_lp.csv
# saved 54 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Panjin_agr_lp.csv
# saved 204 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Shenyang_agr_lp.csv
# saved 204 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Tieling_agr_lp.csv
# saved 80 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Liaoning-Yingkou_agr_lp.csv
# saved 116 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Alashan_agr_lp.csv
# saved 222 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Baotou_agr_lp.csv
# saved 312 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Bayannaoer_agr_lp.csv
# saved 1226 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Chifeng_agr_lp.csv
# saved 518 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Eerduosi_agr_lp.csv
# saved 263 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Huhehaote_agr_lp.csv
# saved 1728 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Hulunbeier_agr_lp.csv
# saved 934 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Tongliao_agr_lp.csv
# saved 13 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Wuhai_agr_lp.csv
# saved 592 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Wulanchabu_agr_lp.csv
# saved 623 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Xilinguole_agr_lp.csv
# saved 832 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Neimenggu-Xingan_agr_lp.csv
# saved 146 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Ningxia-Guyuan_agr_lp.csv
# saved 55 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Ningxia-Shizuishan_agr_lp.csv
# saved 248 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Ningxia-Wuzhong_agr_lp.csv
# saved 85 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Ningxia-Yinchuan_agr_lp.csv
# saved 156 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Ningxia-Zhongwei_agr_lp.csv
# saved 13 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Guoluozangzu_agr_lp.csv
# saved 87 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Haibeizangzu_agr_lp.csv
# saved 171 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Haidong_agr_lp.csv
# saved 245 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Hainanzangzu_agr_lp.csv
# saved 110 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Haiximengguzuzangzu_agr_lp.csv
# saved 42 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Huangnanzangzu_agr_lp.csv
# saved 86 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Xining_agr_lp.csv
# saved 111 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Qinghai-Yushuzangzu_agr_lp.csv
# saved 132 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Binzhou_agr_lp.csv
# saved 147 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Dezhou_agr_lp.csv
# saved 97 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Dongying_agr_lp.csv
# saved 171 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Heze_agr_lp.csv
# saved 153 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Jinan_agr_lp.csv
# saved 159 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Jining_agr_lp.csv
# saved 126 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Liaocheng_agr_lp.csv
# saved 240 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Linyi_agr_lp.csv
# saved 154 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Qingdao_agr_lp.csv
# saved 77 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Rizhao_agr_lp.csv
# saved 111 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Taian_agr_lp.csv
# saved 228 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Weifang_agr_lp.csv
# saved 79 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Weihai_agr_lp.csv
# saved 198 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Yantai_agr_lp.csv
# saved 65 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Zaozhuang_agr_lp.csv
# saved 90 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shandong-Zibo_agr_lp.csv
# saved 3 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Baoshan_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Changning_agr_lp.csv
# saved 14 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Chongming_agr_lp.csv
# saved 9 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Fengxian_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Hongkou_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Huangpu_agr_lp.csv
# saved 7 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Jiading_agr_lp.csv
# saved 10 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Jinshan_agr_lp.csv
# saved 5 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Minhang_agr_lp.csv
# saved 16 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Pudongxin_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Putuo_agr_lp.csv
# saved 8 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Qingpu_agr_lp.csv
# saved 9 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Songjiang_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Xuhui_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanghai-Yangpu_agr_lp.csv
# saved 311 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Ankang_agr_lp.csv
# saved 238 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Baoji_agr_lp.csv
# saved 196 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Changzhi_agr_lp.csv
# saved 210 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Datong_agr_lp.csv
# saved 365 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Hanzhong_agr_lp.csv
# saved 137 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Jincheng_agr_lp.csv
# saved 238 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Jinzhong_agr_lp.csv
# saved 289 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Linfen_agr_lp.csv
# saved 316 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Lüliang_agr_lp.csv
# saved 270 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Shangluo_agr_lp.csv
# saved 158 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Shuozhou_agr_lp.csv
# saved 100 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Taiyuan_agr_lp.csv
# saved 54 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Tongchuan_agr_lp.csv
# saved 183 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Weinan_agr_lp.csv
# saved 136 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Xian_agr_lp.csv
# saved 146 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Xianyang_agr_lp.csv
# saved 371 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Xinzhou_agr_lp.csv
# saved 526 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Yanan_agr_lp.csv
# saved 68 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Yangquan_agr_lp.csv
# saved 548 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Yulin_agr_lp.csv
# saved 208 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Shanxi-Yuncheng_agr_lp.csv
# saved 409 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Abazangzuqiangzu_agr_lp.csv
# saved 173 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Bazhong_agr_lp.csv
# saved 184 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Chengdu_agr_lp.csv
# saved 224 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Dazhou_agr_lp.csv
# saved 76 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Deyang_agr_lp.csv
# saved 570 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Ganzizangzu_agr_lp.csv
# saved 86 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Guangan_agr_lp.csv
# saved 226 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Guangyuan_agr_lp.csv
# saved 157 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Leshan_agr_lp.csv
# saved 705 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Liangshanyizu_agr_lp.csv
# saved 164 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Luzhou_agr_lp.csv
# saved 89 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Meishan_agr_lp.csv
# saved 244 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Mianyang_agr_lp.csv
# saved 165 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Nanchong_agr_lp.csv
# saved 74 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Neijiang_agr_lp.csv
# saved 93 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Panzhihua_agr_lp.csv
# saved 72 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Suining_agr_lp.csv
# saved 168 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Yaan_agr_lp.csv
# saved 172 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Yibin_agr_lp.csv
# saved 55 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Zigong_agr_lp.csv
# saved 79 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Sichuan-Ziyang_agr_lp.csv
# saved 22 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Baodi_agr_lp.csv
# saved 6 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Beichen_agr_lp.csv
# saved 29 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Binhaixin_agr_lp.csv
# saved 7 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Dongli_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Hedong_agr_lp.csv
# saved 24 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Jinghai_agr_lp.csv
# saved 7 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Jinnan_agr_lp.csv
# saved 25 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Jizhou_agr_lp.csv
# saved 1 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Nankai_agr_lp.csv
# saved 19 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Ninghe_agr_lp.csv
# saved 27 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Wuqing_agr_lp.csv
# saved 7 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Tianjin-Xiqing_agr_lp.csv
# saved 389 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Akesu_agr_lp.csv
# saved 36 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Alaer_agr_lp.csv
# saved 390 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Aletai_agr_lp.csv
# saved 289 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Bayinguolengmenggu_agr_lp.csv
# saved 12 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Beitun_agr_lp.csv
# saved 99 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Boertalamenggu_agr_lp.csv
# saved 387 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Changjihuizu_agr_lp.csv
# saved 154 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Hami_agr_lp.csv
# saved 234 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Hetian_agr_lp.csv
# saved 19 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Huyanghe_agr_lp.csv
# saved 427 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Kashi_agr_lp.csv
# saved 19 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Kekedala_agr_lp.csv
# saved 6 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Kelamayi_agr_lp.csv
# saved 128 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Kezilesukeerkezi_agr_lp.csv
# saved 4 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Kunyu_agr_lp.csv
# saved 8 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Shihezi_agr_lp.csv
# saved 12 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Shuanghe_agr_lp.csv
# saved 481 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Tacheng_agr_lp.csv
# saved 7 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Tiemenguan_agr_lp.csv
# saved 78 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Tulufan_agr_lp.csv
# saved 22 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Tumushuke_agr_lp.csv
# saved 13 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Wujiaqu_agr_lp.csv
# saved 79 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Wulumuqi_agr_lp.csv
# saved 410 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xinjiang-Yilihasake_agr_lp.csv
# saved 11 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Ali_agr_lp.csv
# saved 519 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Changdu_agr_lp.csv
# saved 127 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Lasa_agr_lp.csv
# saved 192 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Linzhi_agr_lp.csv
# saved 48 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Naqu_agr_lp.csv
# saved 355 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Rikaze_agr_lp.csv
# saved 198 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Xizang-Shannan_agr_lp.csv
# saved 247 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Baoshan_agr_lp.csv
# saved 361 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Chuxiongyizu_agr_lp.csv
# saved 352 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Dalibaizu_agr_lp.csv
# saved 140 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Dehongdaizujingpozu_agr_lp.csv
# saved 180 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Diqingzangzu_agr_lp.csv
# saved 408 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Honghehanizuyizu_agr_lp.csv
# saved 272 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Kunming_agr_lp.csv
# saved 243 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Lijiang_agr_lp.csv
# saved 297 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Lincang_agr_lp.csv
# saved 141 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Nujianglisuzu_agr_lp.csv
# saved 567 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Puer_agr_lp.csv
# saved 374 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Qujing_agr_lp.csv
# saved 393 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Wenshanzhuangzumiaozu_agr_lp.csv
# saved 226 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Xishuangbannadaizu_agr_lp.csv
# saved 188 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Yuxi_agr_lp.csv
# saved 295 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Yunnan-Zhaotong_agr_lp.csv
# saved 223 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Hangzhou_agr_lp.csv
# saved 79 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Huzhou_agr_lp.csv
# saved 51 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Jiaxing_agr_lp.csv
# saved 144 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Jinhua_agr_lp.csv
# saved 222 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Lishui_agr_lp.csv
# saved 112 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Ningbo_agr_lp.csv
# saved 121 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Quzhou_agr_lp.csv
# saved 106 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Shaoxing_agr_lp.csv
# saved 121 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Taizhou_agr_lp.csv
# saved 150 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Wenzhou_agr_lp.csv
# saved 16 points to /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp/Zhejiang-Zhoushan_agr_lp.csv
# completed!

# %% [markdown]
# ### Filter Points Outside Built-Up Areas
#
# We retain only the rural land points located **outside the built-up area**, as these better represent agricultural land use. This involves:
#
# * Performing a spatial join between rural land points and the built-up area shapefile;
# * Filtering out all points that fall **within** built-up boundaries;
# * Verifying the number of remaining valid points per city to ensure sufficient data coverage for estimating rural land prices.

# %%
input_dir = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/Agr_lp"
builtup_path = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/China_BuiltUp_300kCities_2020/China_BuiltUp_300kCities_2020.shp"


gdf_builtup = gpd.read_file(builtup_path).to_crs("EPSG:4326")
if not gdf_builtup.is_valid.all():
    gdf_builtup["geometry"] = gdf_builtup.buffer(0)

zero_remaining_files = 0
total_files = 0
zero_file_list = []


for filename in os.listdir(input_dir):
    if not filename.endswith(".csv"):
        continue

    total_files += 1
    file_path = os.path.join(input_dir, filename)

    df = pd.read_csv(file_path)
    if df.empty or "lon" not in df.columns or "lat" not in df.columns:
        print(f"Warning: File {filename} is missing required fields or is empty. Skipping.")
        continue

    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["lon"], df["lat"]), crs="EPSG:4326")
    gdf_filtered = gpd.sjoin(gdf, gdf_builtup, predicate="within", how="left")
    gdf_remaining = gdf_filtered[gdf_filtered["index_right"].isna()]  

    if len(gdf_remaining) == 0:
        zero_remaining_files += 1
        zero_file_list.append(filename)

zero_ratio = zero_remaining_files / total_files * 100 if total_files > 0 else 0
print(f"\nTotal number of files: {total_files}")
print(f"Number of files with 0 remaining points: {zero_remaining_files}")
print(f"Proportion: {zero_ratio:.2f}%")

if zero_file_list:
    print("\nList of files with 0 remaining points:")
    for fname in zero_file_list:
        print(f"- {fname}")
# Out:
# /opt/anaconda3/envs/midway-debug/lib/python3.9/site-packages/pyogrio/raw.py:198: RuntimeWarning: /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/China_BuiltUp_300kCities_2020/China_BuiltUp_300kCities_2020.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# Total number of files: 440
# Number of files with 0 remaining points: 9
# Proportion: 2.05%
#
# List of files with 0 remaining points:
# - Shanghai-Yangpu_agr_lp.csv
# - Shanghai-Putuo_agr_lp.csv
# - Beijing-Shijingshan_agr_lp.csv
# - Shanghai-Changning_agr_lp.csv
# - Shanghai-Huangpu_agr_lp.csv
# - Shanghai-Hongkou_agr_lp.csv
# - Chongqing-Dadukou_agr_lp.csv
# - Shanghai-Minhang_agr_lp.csv
# - Tianjin-Nankai_agr_lp.csv

# %% [markdown]
# ### Estimating Average Agricultural Land Price
#
# In highly urbanized cities—such as Beijing and Shanghai—some districts have very limited rural land area, resulting in a small number of usable rural land observations. For cities or counties with **fewer than 5 rural land data points**, we skip the built-up area filtering step and directly compute the average land price using all available points.
#
# The **present value** of rural land is calculated under the standard land valuation framework, treating land as a perpetual income-generating asset:
#
# $$
# P = \frac{R}{r}
# $$
#
# where:
#
# * $P$ is the land price,
# * $R$ is the annual rural land rent (in RMB/m²/year),
# * $r = 0.05$ is the assumed discount rate, reflecting opportunity cost, depreciation, and risk.
#
# The processed city-level average land price results are saved in the file `avg_lp.csv`.

# %%
avg_output_path = "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/avg_lp.csv"

gdf_builtup = gpd.read_file(builtup_path).to_crs("EPSG:4326")
if not gdf_builtup.is_valid.all():
    gdf_builtup["geometry"] = gdf_builtup.buffer(0)

results = []

for filename in os.listdir(input_dir):
    if not filename.endswith(".csv"):
        continue

    file_path = os.path.join(input_dir, filename)
    df = pd.read_csv(file_path)

    if df.empty or "lon" not in df.columns or "lat" not in df.columns or "price_m2" not in df.columns:
        continue

    prov_city = filename.replace("_agr_lp.csv", "")
    try:
        prov, city = prov_city.split("-", 1)
    except ValueError:
        print(f"Warning: Failed to parse province and city from filename: {filename}")
        continue

    if len(df) <= 5:
        avg_price = df["price_m2"].mean() / 0.05
        results.append({
            "prov": prov,
            "city": city,
            "prov_city": prov_city,
            "land_price": avg_price
        })
        continue

    # filter points within and without built-up areas
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["lon"], df["lat"]), crs="EPSG:4326")
    gdf_filtered = gpd.sjoin(gdf, gdf_builtup, predicate="within", how="left")
    gdf_outside = gdf_filtered[gdf_filtered["index_right"].isna()]

    if gdf_outside.empty:
        continue
    else:
        avg_price = gdf_outside["price_m2"].mean() / 0.05
        results.append({
            "prov": prov,
            "city": city,
            "prov_city": prov_city,
            "land_price": avg_price
        })

df_result = pd.DataFrame(results)
df_result.to_csv(avg_output_path, index=False)
print(f"Saved average land price estimates to: {avg_output_path}")
# Out:
# /opt/anaconda3/envs/midway-debug/lib/python3.9/site-packages/pyogrio/raw.py:198: RuntimeWarning: /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/China_BuiltUp_300kCities_2020/China_BuiltUp_300kCities_2020.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# Saved average land price estimates to: /Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/avg_lp.csv

# %% [markdown]
# ## OLS fitting rent curve
#
# ### Land Output Elasticity and Land Price Estimation
#
# We assume a Cobb-Douglas production function:
#
# $$
# Y = A \cdot L^{\alpha} \cdot K^{\beta} \cdot N^{\gamma}
# $$
#
#
# Assuming land is a capitalized asset, its price equals to its marginal product:
#
# $$
# P_L = \alpha \cdot \frac{Y}{L}
# $$
#
# If housing price approximates per-unit output value, we estimate land price as:
#
# $$
# P_L = \alpha \cdot P_{\text{house}}
# $$
#
# We set $\alpha = 0.3$, based on Zhang and Jin (2012), who estimate the land elasticity from a translog production function and find $\alpha \approx 0.293$. Due to limited data for city-level estimation, we adopt this unified value throughout the analysis.

# %%
def fit_urban_land_rent_curve(prov, city, alpha=0.3,
                               base_dir="/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/City_hp"):
    """
    Given a city and alpha, estimate urban land rent curve:
    1. Load city CSV
    2. Compute land_price = alpha * house_price
    3. Identify city center (highest land_price)
    4. Compute distances from each point to center
    5. Fit land_price ~ dist

    Returns: (fitted OLS model, processed DataFrame)
    """

    filename = f"{prov}-{city}_hp.csv"
    file_path = os.path.join(base_dir, filename)
    if not os.path.exists(file_path):
        print(f"File not found: {file_path}")
        return None, None


    df = pd.read_csv(file_path)
    if "价格" not in df.columns or "lng84" not in df.columns or "lat84" not in df.columns:
        print(f"Missing required columns in: {filename}")
        return None, None

 
    df = df.rename(columns={"价格": "house_price"})
    df["land_price"] = df["house_price"] * alpha


    max_idx = df["land_price"].idxmax()
    center_coord = (df.loc[max_idx, "lat84"], df.loc[max_idx, "lng84"])

    def calc_dist(row):
        return geodesic((row["lat84"], row["lng84"]), center_coord).km

    df["dist"] = df.apply(calc_dist, axis=1)
    df = df.dropna(subset=["land_price", "dist"])


    X = sm.add_constant(df["dist"])
    y = df["land_price"]
    model = sm.OLS(y, X).fit()

    return center_coord,model, df

# %%
(center_lat, center_lon), model, df_result = fit_urban_land_rent_curve("Zhejiang","Hangzhou", alpha=0.3)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             land_price   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     463.8
# Date:                Thu, 29 May 2025   Prob (F-statistic):           2.51e-98
# Time:                        17:16:13   Log-Likelihood:                -49109.
# No. Observations:                4846   AIC:                         9.822e+04
# Df Residuals:                    4844   BIC:                         9.823e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.586e+04    192.447     82.407      0.000    1.55e+04    1.62e+04
# dist        -329.4120     15.295    -21.537      0.000    -359.397    -299.427
# ==============================================================================
# Omnibus:                     1620.127   Durbin-Watson:                   1.271
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6306.891
# Skew:                           1.625   Prob(JB):                         0.00
# Kurtosis:                       7.547   Cond. No.                         27.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Welfare Loss Calculation Function – OLS
#
# ### Computing the Theoretical Urban Boundary
#
# Given the `prov`, `city`, and the estimated rent-distance curve (from the OLS model), we proceed as follows:
#
# * First, retrieve the corresponding **rural land price** from `avg_lp.csv` for the specified city.
# * If a city-level match is not available, fall back to the **provincial average** rural land price.
#
# Using the fitted rent curve, we then calculate the **theoretical urban boundary**, defined as the distance from the city center where the urban land rent equals the rural land price. This is the point at which it becomes unprofitable for the city to expand further under market-based land allocation.

# %%
def get_urban_rural_boundary_edge(prov, city, model,
                                   avg_lp_path="/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Cleaned/avg_lp.csv"):
    """
    Given province and city, and a land rent regression model (land_price ~ dist),
    return the implied urban edge (distance where land_price equals rural land_price).

    Returns:
        float (edge in km) or None if not found
    """

    key = f"{prov}-{city}"
    df_lp = pd.read_csv(avg_lp_path)
    df_lp = df_lp.dropna(subset=["prov_city", "land_price"])

    match = df_lp[df_lp["prov_city"] == key]
    if not match.empty:
        rural_lp = match["land_price"].values[0]
    else:
        prov_matches = df_lp[df_lp["prov"] == prov]
        if not prov_matches.empty:
            rural_lp = prov_matches["land_price"].mean()
            print(f"Using provincial average land price for {prov}: {rural_lp:.4f}")
        else:
            print(f"No land price data available for {key} or {prov}")
            return None

    beta0 = model.params["const"]
    beta1 = model.params["dist"]

    if beta1 == 0:
        print("Warning: distance coefficient is zero.")
        return None

    edge = (rural_lp - beta0) / beta1
    return edge if edge > 0 else None

# %%
edge_km = get_urban_rural_boundary_edge("Zhejiang","Hangzhou", model)
print(f"Estimated urban edge distance (km): {edge_km:.2f}" if edge_km else "No valid edge found")
# Out:
# Estimated urban edge distance (km): 48.11

# %% [markdown]
# ### Comparison of Actual and Theoretical Urban Area
#
# Using the location with the highest housing price as the city center (i.e., the circle’s center), we draw a circle with a radius equal to the theoretical urban-rural boundary. This visualizes and compares the actual built-up area with the idealized circular urban footprint under the theoretical model.

# %%
def find_shp_file(prov, city, root_path="/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Raw/China_BuiltUp_300kCities_2020"):

    prov_folder = os.path.join(root_path, prov)
    if not os.path.isdir(prov_folder):
        print(f"Warning: Province folder does not exist: {prov_folder}")
        return None

    shp_files = [f for f in os.listdir(prov_folder) if f.endswith(".shp")]
    city_lower = city.lower()
    prov_lower = prov.lower()

    matched_file = None

    for f in shp_files:
        if city_lower in f.lower():
            matched_file = os.path.join(prov_folder, f)
            break
    if not matched_file:
        for f in shp_files:
            if prov_lower in f.lower():
                matched_file = os.path.join(prov_folder, f)
                break

    return matched_file

def analyze_builtup_vs_theory_edge(prov, city, center_lat, center_lon, radius_km,
                                    root_path="/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Raw/China_BuiltUp_300kCities_2020"):


    matched_file = find_shp_file(prov, city, root_path)
    if not matched_file:
        print(f"Error: No matching shapefile found for {prov}-{city}.")
        return

    gdf_built = gpd.read_file(matched_file).to_crs("EPSG:3857")
    gdf_built["geometry"] = gdf_built["geometry"].buffer(0)
    gdf_built = gdf_built[gdf_built.is_valid]  

    center_proj = gpd.GeoSeries([Point(center_lon, center_lat)], crs="EPSG:4326").to_crs("EPSG:3857").iloc[0]
    circle_geom = center_proj.buffer(radius_km * 1000)  

    gdf_circle = gpd.GeoDataFrame(geometry=[circle_geom], crs="EPSG:3857")
    intersection = gdf_built.intersects(circle_geom)

    gdf_circle = gpd.GeoDataFrame(geometry=[circle_geom], crs="EPSG:3857")
    intersection = gdf_built.intersects(circle_geom)

    ax = gdf_built.plot(edgecolor='black', facecolor='none', linewidth=0.5)
    gdf_circle.plot(ax=ax, edgecolor='red', facecolor='none', linewidth=2)
    plt.title(f"Built-up vs Theoretical Edge for {city}, {prov}")
    plt.show()

    overlap_ratio = intersection.sum() / len(gdf_built)
    print(f"Overlap ratio of built-up area within {radius_km} km of center: {overlap_ratio:.2f}")

# %%
analyze_builtup_vs_theory_edge("Zhejiang","Hangzhou", center_lat, center_lon, edge_km)
# Out:
# Overlap ratio of built-up area within 48.105531952688374 km of center: 1.00

# %% [markdown]
# ### Measuring the Distance Between Actual and Theoretical Urban-Rural Boundaries
#
# Due to the highly irregular shape of urban edges, it is difficult to directly measure the overall distance between the actual and theoretical urban-rural boundaries. To address this, my algorithm constructs a theoretical boundary as a circle centered on the city center with a given radius. It then samples 300 points along the **actual built-up boundary** that lie within this theoretical boundary. The average distance between these sampled points and the theoretical boundary is computed and used as a summary measure of the **gap between actual and theoretical urban-rural boundaries**.

# %%
def mean_internal_radius_gap_op(prov, city, center, R,
    root_path="/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Raw/China_BuiltUp_300kCities_2020",
    crs_metric="EPSG:3857", sample_count=300, simplify_tolerance=5.0):
    """
    Compute the average internal radius gap: the average of (R - d),
    where d is the distance from each sampled built-up area boundary point
    (within radius R) to the city center.

    Args:
        prov, city         : Province and city name, used to locate the shapefile.
        center             : City center coordinates (lon, lat).
        R                  : Theoretical urban-rural boundary radius (in meters).
        root_path          : Root directory containing provincial shapefiles.
        crs_metric         : Projected CRS for distance calculations (default: EPSG:3857).
        sample_count       : Total number of points to sample along all outer boundaries.
        simplify_tolerance : Tolerance for simplifying the polygon boundaries (in meters) to speed up sampling.

    Returns:
        Mean internal gap (in kilometers); returns 0.0 if no valid points found.
    """

    shp_path = find_shp_file(prov, city, root_path)
    if shp_path is None:
        raise FileNotFoundError(f"Shapefile not found: prov={prov}, city={city}")

    gdf = gpd.read_file(shp_path).to_crs(crs_metric)
    builtup_union = gdf.unary_union
    
    Origin = gpd.GeoSeries([Point(center)], crs="EPSG:4326").to_crs(crs_metric).iloc[0]

    if builtup_union.geom_type == "Polygon":
        exteriors = [builtup_union.exterior.simplify(simplify_tolerance)]
    else:
        exteriors = [poly.exterior.simplify(simplify_tolerance) for poly in builtup_union.geoms]

    lengths = [ext.length for ext in exteriors]
    total_length = sum(lengths)
    if total_length == 0:
        return 0.0

    all_pts = []
    for ext, L in zip(exteriors, lengths):
        n = max(int(sample_count * (L / total_length)), 1)
        dists = np.linspace(0, L, n, endpoint=False)
        all_pts.extend([ext.interpolate(d) for d in dists])

    gaps = []
    for pt in all_pts:
        d = pt.distance(Origin)
        if d <= R:
            gaps.append(R - d)

    return float(np.mean(gaps)) / 1000 if gaps else 0.0

# %%
gap_km = mean_internal_radius_gap_op(
    "Zhejiang","Hangzhou",
    center=(center_lon, center_lat),
    R=edge_km * 1000,
    root_path= "/Users/yxy/UChi/Spring2025/MACS30123/Final_project/Data/Raw/China_BuiltUp_300kCities_2020",
)
print(f"Mean internal radius gap for {prov}-{city}: {gap_km:.2f} km")
# Out:
# /var/folders/4g/6_8lhyp147394q93651p5kyw0000gn/T/ipykernel_46914/3692902767.py:27: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   builtup_union = gdf.unary_union
# Mean internal radius gap for Neimenggu-Baotou: 26.48 km

# %% [markdown]
# ### Welfare Loss Calculation Function – OLS
#
# Given the distance between the actual and theoretical urban-rural boundaries and an estimated OLS rent-distance function, this function computes:
#
# * the **welfare loss** as the area of a triangle between the two boundaries, and
# * the **welfare loss as a proportion** of the total theoretical land rent under full expansion.

# %%
def compute_welfare_loss_triangle_linear(model, edge_km, gap_km):
    """
    Compute the welfare loss as the area of a triangle under a linear rent curve:
      r(d) = beta_0 + beta_1 * d

    Args:
      model    : Fitted statsmodels OLS result (regression of price on distance)
      edge_km  : Theoretical urban boundary radius (in kilometers)
      gap_km   : Average distance between theoretical and actual urban boundary (in kilometers)

    Returns:
      loss     : Welfare loss triangle area (in price * km units)
    """
    dist_a = edge_km - gap_km
    if dist_a <= 0:
        return 0.0

    slope_name = [n for n in model.params.index if n != "const"][0]
    beta1 = model.params[slope_name]

    loss = -0.5 * beta1 * gap_km**2

    S = 0.5 * edge_km * (- beta1 * edge_km)

    loss_ratio = loss / S if S != 0 else 0.0

    return loss,loss_ratio

# %%
loss,loss_ratio = compute_welfare_loss_triangle_linear(model, edge_km, gap_km)
print(f"Welfare loss triangle area: {loss:.2f}")
print(f"Welfare loss ratio: {loss_ratio:.2%}")
# Out:
# Welfare loss triangle area: 75459.65
# Welfare loss ratio: 30.54%
